# %%
# %pip install jsonlines > /dev/null
# %pip install matplotlib > /dev/null
# %pip install numpy > /dev/null
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from Initializer import Initializer

Initializer.run()

# %%
from plotters import PlottersBank

plotters_bank = PlottersBank()

# %%
plotters_bank.projects_within_one_day.show()

# %%
plotters_bank.projects_per_user.show()

# %%
plotters_bank.switching_projects.show()

# %%
plotters_bank.activity_by_weekday.show()

# %%
plotters_bank.performance_per_weekday.show()

# %%
plotters_bank.del_to_add.show()

# %%
plotters_bank.del_to_add_langs.show()

# %%
plotters_bank.breaks.show()

# %%
plotters_bank.activity_per_hour.show()

# %%
plotters_bank.activity_per_hour_langs.show()

# %%
plotters_bank.performance_per_hour_total.show()

# %%
plotters_bank.performance_per_hour_langs.show()

# %%
plotters_bank.data_gathered.show()

# %%
plotters_bank.languages_total.show()
