# %%
# %pip install jsonlines > /dev/null
# %pip install matplotlib > /dev/null
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
import jsonlines
import matplotlib.pyplot as plt

# %%
DATA_FILE_PATH = './data/2022/10/12.jsonl'

# %%
with jsonlines.open(DATA_FILE_PATH) as reader:
    raw_data = list(reader)

# %%
raw_data
# Out:
# [{'additions': 117,
#   'deletions': 11,
#   'actions': 21,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 117, 'deletions': 11, 'actions': 21}},
#   'start': '2022-10-12T00:09:47.212+02:00',
#   'end': '2022-10-12T00:10:03.635+02:00'},
#  {'additions': 0,
#   'deletions': 7,
#   'actions': 9,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 0, 'deletions': 7, 'actions': 9}},
#   'start': '2022-10-12T00:10:45.483+02:00',
#   'end': '2022-10-12T00:10:47.218+02:00'},
#  {'additions': 190,
#   'deletions': 64,
#   'actions': 11,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 190, 'deletions': 64, 'actions': 11}},
#   'start': '2022-10-12T00:23:02.352+02:00',
#   'end': '2022-10-12T00:23:32.200+02:00'},
#  {'additions': 14,
#   'deletions': 11,
#   'actions': 27,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 14, 'deletions': 11, 'actions': 27}},
#   'start': '2022-10-12T00:23:33.763+02:00',
#   'end': '2022-10-12T00:23:49.651+02:00'},
#  {'additions': 9,
#   'deletions': 11,
#   'actions': 14,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 9, 'deletions': 11, 'actions': 14}},
#   'start': '2022-10-12T00:26:15.421+02:00',
#   'end': '2022-10-12T00:26:44.526+02:00'},
#  {'additions': 85,
#   'deletions': 111,
#   'actions': 6,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 85, 'deletions': 111, 'actions': 6}},
#   'start': '2022-10-12T00:26:45.834+02:00',
#   'end': '2022-10-12T00:27:00.431+02:00'},
#  {'additions': 9,
#   'deletions': 11,
#   'actions': 3,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 9, 'deletions': 11, 'actions': 3}},
#   'start': '2022-10-12T00:28:01.521+02:00',
#   'end': '2022-10-12T00:28:02.709+02:00'},
#  {'additions': 23,
#   'deletions': 6,
#   'actions': 27,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 23, 'deletions': 6, 'actions': 27}},
#   'start': '2022-10-12T00:31:47.500+02:00',
#   'end': '2022-10-12T00:32:08.433+02:00'},
#  {'additions': 1183,
#   'deletions': 96,
#   'actions': 26,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 1183, 'deletions': 96, 'actions': 26}},
#   'start': '2022-10-12T00:35:27.361+02:00',
#   'end': '2022-10-12T00:35:57.319+02:00'},
#  {'additions': 662,
#   'deletions': 21,
#   'actions': 6,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 662, 'deletions': 21, 'actions': 6}},
#   'start': '2022-10-12T00:35:57.632+02:00',
#   'end': '2022-10-12T00:36:22.759+02:00'},
#  {'additions': 44,
#   'deletions': 4,
#   'actions': 6,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 44, 'deletions': 4, 'actions': 6}},
#   'start': '2022-10-12T00:37:38.996+02:00',
#   'end': '2022-10-12T00:37:58.745+02:00'},
#  {'additions': 35,
#   'deletions': 16,
#   'actions': 5,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 35, 'deletions': 16, 'actions': 5}},
#   'start': '2022-10-12T00:38:42.381+02:00',
#   'end': '2022-10-12T00:38:47.214+02:00'},
#  {'additions': 105,
#   'deletions': 59,
#   'actions': 26,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 105, 'deletions': 59, 'actions': 26}},
#   'start': '2022-10-12T00:39:21.823+02:00',
#   'end': '2022-10-12T00:39:51.599+02:00'},
#  {'additions': 4,
#   'deletions': 2,
#   'actions': 10,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 4, 'deletions': 2, 'actions': 10}},
#   'start': '2022-10-12T00:40:59.759+02:00',
#   'end': '2022-10-12T00:41:15.222+02:00'},
#  {'additions': 39,
#   'deletions': 28,
#   'actions': 6,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 39, 'deletions': 28, 'actions': 6}},
#   'start': '2022-10-12T00:41:34.892+02:00',
#   'end': '2022-10-12T00:41:46.108+02:00'},
#  {'additions': 265,
#   'deletions': 158,
#   'actions': 4,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 265, 'deletions': 158, 'actions': 4}},
#   'start': '2022-10-12T00:42:33.725+02:00',
#   'end': '2022-10-12T00:42:34.791+02:00'},
#  {'additions': 76,
#   'deletions': 22,
#   'actions': 20,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 76, 'deletions': 22, 'actions': 20}},
#   'start': '2022-10-12T00:43:21.146+02:00',
#   'end': '2022-10-12T00:43:31.238+02:00'},
#  {'additions': 268,
#   'deletions': 194,
#   'actions': 23,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 268, 'deletions': 194, 'actions': 23}},
#   'start': '2022-10-12T00:44:00.468+02:00',
#   'end': '2022-10-12T00:44:28.080+02:00'},
#  {'additions': 20,
#   'deletions': 22,
#   'actions': 16,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 20, 'deletions': 22, 'actions': 16}},
#   'start': '2022-10-12T00:47:27.513+02:00',
#   'end': '2022-10-12T00:47:32.357+02:00'},
#  {'additions': 24,
#   'deletions': 10,
#   'actions': 6,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 24, 'deletions': 10, 'actions': 6}},
#   'start': '2022-10-12T00:48:50.701+02:00',
#   'end': '2022-10-12T00:48:55.843+02:00'},
#  {'additions': 384,
#   'deletions': 292,
#   'actions': 9,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 384, 'deletions': 292, 'actions': 9}},
#   'start': '2022-10-12T00:49:26.768+02:00',
#   'end': '2022-10-12T00:49:53.492+02:00'},
#  {'additions': 29,
#   'deletions': 35,
#   'actions': 42,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 29, 'deletions': 35, 'actions': 42}},
#   'start': '2022-10-12T00:49:58.963+02:00',
#   'end': '2022-10-12T00:50:28.881+02:00'},
#  {'additions': 12,
#   'deletions': 10,
#   'actions': 17,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 12, 'deletions': 10, 'actions': 17}},
#   'start': '2022-10-12T00:50:29.901+02:00',
#   'end': '2022-10-12T00:50:39.563+02:00'},
#  {'additions': 29,
#   'deletions': 49,
#   'actions': 19,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 29, 'deletions': 49, 'actions': 19}},
#   'start': '2022-10-12T00:51:01.115+02:00',
#   'end': '2022-10-12T00:51:28.117+02:00'},
#  {'additions': 44,
#   'deletions': 12,
#   'actions': 29,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 44, 'deletions': 12, 'actions': 29}},
#   'start': '2022-10-12T00:51:38.909+02:00',
#   'end': '2022-10-12T00:51:55.646+02:00'},
#  {'additions': 346,
#   'deletions': 302,
#   'actions': 42,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 346, 'deletions': 302, 'actions': 42}},
#   'start': '2022-10-12T00:52:17.546+02:00',
#   'end': '2022-10-12T00:52:47.536+02:00'},
#  {'additions': 16,
#   'deletions': 19,
#   'actions': 19,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 16, 'deletions': 19, 'actions': 19}},
#   'start': '2022-10-12T00:52:51.853+02:00',
#   'end': '2022-10-12T00:53:10.253+02:00'},
#  {'additions': 307,
#   'deletions': 28,
#   'actions': 17,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 307, 'deletions': 28, 'actions': 17}},
#   'start': '2022-10-12T00:54:42.718+02:00',
#   'end': '2022-10-12T00:55:04.291+02:00'},
#  {'additions': 22,
#   'deletions': 36,
#   'actions': 19,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 22, 'deletions': 36, 'actions': 19}},
#   'start': '2022-10-12T00:55:36.115+02:00',
#   'end': '2022-10-12T00:56:05.463+02:00'},
#  {'additions': 48,
#   'deletions': 12,
#   'actions': 9,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 48, 'deletions': 12, 'actions': 9}},
#   'start': '2022-10-12T00:56:32.410+02:00',
#   'end': '2022-10-12T00:56:43.442+02:00'},
#  {'additions': 524,
#   'deletions': 292,
#   'actions': 25,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 524, 'deletions': 292, 'actions': 25}},
#   'start': '2022-10-12T00:57:16.904+02:00',
#   'end': '2022-10-12T00:57:45.736+02:00'},
#  {'additions': 8,
#   'deletions': 8,
#   'actions': 4,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 8, 'deletions': 8, 'actions': 4}},
#   'start': '2022-10-12T00:57:50.813+02:00',
#   'end': '2022-10-12T00:57:52.915+02:00'},
#  {'additions': 26,
#   'deletions': 32,
#   'actions': 17,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 26, 'deletions': 32, 'actions': 17}},
#   'start': '2022-10-12T00:59:18.612+02:00',
#   'end': '2022-10-12T00:59:28.073+02:00'},
#  {'additions': 138,
#   'deletions': 63,
#   'actions': 20,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 138, 'deletions': 63, 'actions': 20}},
#   'start': '2022-10-12T01:00:13.568+02:00',
#   'end': '2022-10-12T01:00:39.806+02:00'},
#  {'additions': 53,
#   'deletions': 12,
#   'actions': 9,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 53, 'deletions': 12, 'actions': 9}},
#   'start': '2022-10-12T01:00:45.819+02:00',
#   'end': '2022-10-12T01:00:56.644+02:00'},
#  {'additions': 17,
#   'deletions': 36,
#   'actions': 26,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 17, 'deletions': 36, 'actions': 26}},
#   'start': '2022-10-12T01:09:59.663+02:00',
#   'end': '2022-10-12T01:10:27.639+02:00'},
#  {'additions': 8,
#   'deletions': 18,
#   'actions': 17,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 8, 'deletions': 18, 'actions': 17}},
#   'start': '2022-10-12T01:10:33.149+02:00',
#   'end': '2022-10-12T01:10:57.563+02:00'},
#  {'additions': 6,
#   'deletions': 8,
#   'actions': 6,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 6, 'deletions': 8, 'actions': 6}},
#   'start': '2022-10-12T01:11:05.027+02:00',
#   'end': '2022-10-12T01:11:12.004+02:00'},
#  {'additions': 69,
#   'deletions': 17,
#   'actions': 25,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 69, 'deletions': 17, 'actions': 25}},
#   'start': '2022-10-12T01:11:36.074+02:00',
#   'end': '2022-10-12T01:12:00.333+02:00'},
#  {'additions': 358,
#   'deletions': 24,
#   'actions': 7,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 358, 'deletions': 24, 'actions': 7}},
#   'start': '2022-10-12T01:16:46.090+02:00',
#   'end': '2022-10-12T01:16:47.793+02:00'},
#  {'additions': 33,
#   'deletions': 47,
#   'actions': 23,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 33, 'deletions': 47, 'actions': 23}},
#   'start': '2022-10-12T01:17:55.821+02:00',
#   'end': '2022-10-12T01:18:12.503+02:00'},
#  {'additions': 18,
#   'deletions': 24,
#   'actions': 9,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 18, 'deletions': 24, 'actions': 9}},
#   'start': '2022-10-12T01:18:26.598+02:00',
#   'end': '2022-10-12T01:18:37.939+02:00'},
#  {'additions': 381,
#   'deletions': 27,
#   'actions': 13,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 381, 'deletions': 27, 'actions': 13}},
#   'start': '2022-10-12T01:19:39.629+02:00',
#   'end': '2022-10-12T01:20:09.449+02:00'},
#  {'additions': 23,
#   'deletions': 446,
#   'actions': 25,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 23, 'deletions': 446, 'actions': 25}},
#   'start': '2022-10-12T01:20:12.283+02:00',
#   'end': '2022-10-12T01:20:41.243+02:00'},
#  {'additions': 92,
#   'deletions': 7,
#   'actions': 99,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 92, 'deletions': 7, 'actions': 99}},
#   'start': '2022-10-12T01:20:42.738+02:00',
#   'end': '2022-10-12T01:21:12.219+02:00'},
#  {'additions': 55,
#   'deletions': 49,
#   'actions': 23,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 55, 'deletions': 49, 'actions': 23}},
#   'start': '2022-10-12T01:23:01.855+02:00',
#   'end': '2022-10-12T01:23:17.475+02:00'},
#  {'additions': 268,
#   'deletions': 24,
#   'actions': 20,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 268, 'deletions': 24, 'actions': 20}},
#   'start': '2022-10-12T01:23:40.673+02:00',
#   'end': '2022-10-12T01:23:58.149+02:00'},
#  {'additions': 41,
#   'deletions': 76,
#   'actions': 54,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 41, 'deletions': 76, 'actions': 54}},
#   'start': '2022-10-12T01:24:13.071+02:00',
#   'end': '2022-10-12T01:24:39.623+02:00'},
#  {'additions': 41,
#   'deletions': 33,
#   'actions': 34,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 41, 'deletions': 33, 'actions': 34}},
#   'start': '2022-10-12T01:24:50.479+02:00',
#   'end': '2022-10-12T01:25:12.717+02:00'},
#  {'additions': 0,
#   'deletions': 382,
#   'actions': 6,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 0, 'deletions': 382, 'actions': 6}},
#   'start': '2022-10-12T01:25:53.005+02:00',
#   'end': '2022-10-12T01:25:55.220+02:00'},
#  {'additions': 17,
#   'deletions': 4,
#   'actions': 15,
#   'workspaceNameHash': '800e28181a0040c4721bb9c7c949696c0b726ddde5e0887adb2cccadc6113fcb',
#   'languages': {'python': {'additions': 17, 'deletions': 4, 'actions': 15}},
#   'start': '2022-10-12T01:26:27.828+02:00',
#   'end': '2022-10-12T01:26:46.875+02:00'}]

# %%
additions = [v for d in raw_data for v in [0, d['additions']]]
deletions = [-v for d in raw_data for v in [0, d['deletions']]]
dates = [datetime.fromisoformat(v).timestamp() for d in raw_data for v in [d['start'], d['end']]]

# %%
plt.figure(figsize=(35, 18))
plt.step(dates, additions)
plt.step(dates, deletions)
